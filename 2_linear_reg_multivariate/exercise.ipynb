# %%
import pandas as pd
import sklearn.linear_model
import numpy as np

# %%
df = pd.read_csv('./Exercise/hiring.csv')
df
from word2number import w2n

# %%
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           5                    8.0                           9      50000
# 1           5                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           5                   10.0                          10      65000
# 4           5                    9.0                           6      70000
# 5           5                    7.0                          10      62000
# 6           5                    NaN                           7      72000
# 7           5                    7.0                           8      80000

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e100d27982f9> in <module>
#       1 df.experience.fillna(0)
#       2 df.experience = df.experience.fillna(0)
# ----> 3 df.experience = w2n.word_to_num(str(df.experience))
#       4 df
#
# ~/anaconda3/lib/python3.7/site-packages/word2number/w2n.py in word_to_num(number_sentence)
#     152     # Error message if the user enters invalid input!
#     153     if len(clean_numbers) == 0:
# --> 154         raise ValueError("No valid number words found! Please enter a valid number word (eg. two million twenty three thousand and forty nine)")
#     155
#     156     # Error if user enters million,billion, thousand or decimal point twice
#
# ValueError: No valid number words found! Please enter a valid number word (eg. two million twenty three thousand and forty nine)
